# %%
from langchain.docstore.document import Document
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
import os
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Extract the list part from the string
import re
from IPython.display import Image, display, Markdown

# from config import faiss_folder
import time

from langchain_core.messages import HumanMessage 
from operator import itemgetter


from dotenv import load_dotenv

load_dotenv(override=True)


def get_faiss_files(directory: str)-> list:

    '''This function will return all the files present in the directory folder
    ending with .faiss
    '''
    faiss_files = []
    
    try:
        # Iterate through the files in the specified directory
        for file_name in os.listdir(directory):
            # Check if the file starts with db_ ends with .faiss
            # if file_name.startswith("combined_") and file_name.endswith(".faiss"):
            if file_name.endswith(".faiss"):
                faiss_files.append(file_name)
                
        print(f"[INFO]: Found the following faiss indexes in the {directory} : [{faiss_files}]")
    except FileNotFoundError:
        print(f"Error: The directory '{directory}' does not exist.")
    except PermissionError:
        print(f"Error: Permission denied to access '{directory}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

    return faiss_files



def extract_docs_db(faiss_folder_path: str)-> list:
    """
    This function will extract all the faiss objects representing the document chunks from my vector store ( faiss_folder_path)
    
    """
    
    faiss_folder = faiss_folder_path
    vector_names = get_faiss_files(faiss_folder_path) # Extracting all the files present in the faiss folder
    

    # Handle the case when no vector files are found
    if not vector_names:
        print("No vector files found in the specified directory.")
        error_ = "[ERROR]: No faiss indexes found, Please try again or check if you have stored the data into vector store.! or Check if the faiss_folder_path is correct or not"
        return   error_# Return an empty list if no vector names are found

    loaded_relevant_dbs_name = [] # List of all the vector dbs present in VECTOR_STORE/faiss_store are loaded
    embeddings = OpenAIEmbeddings()

    for filename in vector_names: 
        if filename.endswith(".faiss"):
            index_name = filename[:-6]  # Remove '.faiss' for loading
            print("index", index_name)
            try:
                loaded_db = FAISS.load_local(folder_path = faiss_folder, index_name=index_name, embeddings=embeddings, allow_dangerous_deserialization=True)
                loaded_relevant_dbs_name.append(loaded_db)
                
            except FileNotFoundError:
                print(f"Error: The file '{filename}' was not found.")
            except Exception as e:
                print(f"An error occurred while loading '{filename}': {e}")

    return loaded_relevant_dbs_name



def query_documents_context_extraction(query: str, combined_db: list, k_doc: int = 6, score_threshold: float = 0.6):
    """
    Extracts the most relevant chunks across multiple vector databases representing each uploaded file based on a the user query in the converstation.

    This function performs similarity searches on the provided 
    document-wise databases objetcs #langchain_community.vectorstores.faiss.FAISS
    for each query in sub_queries: this function retrieves the most relevant context (documents). 
    and filters the results based on a score threshold.

    Parameters:
        user_query (str): List of the search queries to be compared against the documents.
        combined_db (list): A list of document-wise faiss object to search through.
        k_doc (int): The number of top documents to retrieve from each database.
        score_threshold (float): The minimum score required for a document to be included in the results.

    Returns:
        list: A list of tuples containing the filtered documents and their scores.
              Each tuple is in the format (document, score).
    
    Example:
        results = compare_documents("example query", [Combined_DB.faiss], 5, 0.75)
    """
    
    try:
        results = []
        
        for db_ in combined_db:
            retriever = db_.as_retriever(
                search_type="similarity_score_threshold",
                search_kwargs={"score_threshold": score_threshold,
                                "k": k_doc}    
            )
            
            
            docs_ = retriever.invoke(query)
            print("DOCS_:", docs_)       
            results.extend(docs_)

        # Need to include this logic for removing any duplicates if present - not a issue of concern for now

        print("[INF0]: Successfully extracted the relevant chunks for answer generation")
        
        # return docs_without_duplicates
        return results
    except Exception as e:
        print(f"[ERROR]: Error occured during the chunks retreival.\n query_documents_context_extraction \ {e} ")

# creating individual chunks 

def ASK_Question_On_Your_Documents(user_query: str, document_wise_dbs, model_name: str = "gpt-4o"):

    '''This function is used to generate answer to the user query from the list of vector stores representing the context data for 
    generating answer to the user query.

    db_Aptusdatalabs.faiss which contains the combined data of all content present in the aptus website.
    The reason for giving a list of vector index is that in future more sources can be added like documents, texts, etc as the 
    data source for answering the user query

    Logic:
    1- Extracting all the faiss objects and loading it to the system.
    2- Taking the user query and run similarity search on all the vector stores. For now we have only one faiss store
    3- The retrieved chunks will be sent to the llm along with the sources
    4- The llm response will be returned in a format : answer = {"chatbot_response":"", source: []}
    Note: We are extracting the response in this format so that we can show the sources too in the responce generated.

    Parameters:
    - user_query (str): The user query in the UI
    - faiss_folder (list): The folder containing the vector indexes
    - document_wise_dbs: All the vector indexes found in the faiss folder
    - model_name: GPT Model to be used like gpt-3.5-turbo
    
    Returns:
    - Response (dict): The answer generated by the llm to the user query after taking the context. Format= {"chatbot_response":"", source: []}
 
    '''

     # Time calculation
    start_time = time.time()
    

    docs_ = query_documents_context_extraction(user_query, document_wise_dbs, score_threshold=0.45) #extracting the relevant chunks to the query
    print(f"[INFO]: No of chunks extracted: {len(docs_)}")

    # Calling the llm for analysis
    # Post vector loading anc hunks extraction
    if not docs_:
        return "Sorry, I couldn't find any relevant information related to your query. Kindly contact the Aptus team!"
    else:
        try:
            llm = ChatOpenAI(model = model_name)
            sources = []
            context_ = """ """
            for doc in docs_:
                # Adding only the page content into the context 
                sources.append(doc.metadata['source'])
                context_ += f"source:{doc.metadata['source']} {doc.page_content} \n\n"
            

            instructions = """ Give a short answer to the user query based on the provided documents.           
                            """

            final_prompt = ChatPromptTemplate.from_messages(
                [
                    (
                        "system",
                        "You are a bot that provides concise, direct answers. You can elaborate if the user requests it, but keep responses short by default. Always format answers in Markdown.",
                    ),
                    ("human", f"{instructions}"),
                    ("human", f"{user_query}"),                    
                    ("human", "documents: {input}"),
                ]
            )
            
            print("[INFO]: Generating answer to the given query.")

            chain = {"input": itemgetter("input")} | final_prompt | llm | StrOutputParser()

            ans = chain.invoke({"input": context_.strip()})
            # display(Markdown(ans))
            ans = {"chatbot_response":ans, "sources":sources}
            return ans
        
        except Exception as e:
            print("[ERROR]: Could not Generate answer to this question")
            return f"<p style='color: red; font-weight: bold;'>Could not Generate answer to this question</p>"
            print(e)

# %%
cd .
# Out:
# d:\projects_aptus\Aptus_BOT
# C:\Users\Lenovo\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
faiss_folder_path = "./VECTOR_STORE/faiss_store"
document_wise_dbs = extract_docs_db(faiss_folder_path)
print("[INFO]: Successfully loaded the vector store in the system")
# Out:
# [INFO]: Found the following faiss indexes in the ./VECTOR_STORE/faiss_store : [['db_Aptusdatalabs.faiss']]
# index db_Aptusdatalabs
# [INFO]: Successfully loaded the vector store in the system

# %%
document_wise_dbs

# %%
 # Calling the llm for analysis
user_query = "APTUS DATA LABS SERVICES"
# ans = query_documents_context_extraction(user_query, document_wise_dbs)
# ans 
ans =  ASK_Question_On_Your_Documents(user_query, document_wise_dbs, "gpt-4o") 
# display(Markdown(ans[]))
# Out:
# DOCS_: [Document(metadata={'source': 'https://aptusdatalabs.com/amazon-web-services/', 'loc': 'https://aptusdatalabs.com/amazon-web-services/', 'lastmod': '2024-09-14T11:13:51+00:00'}, page_content="Amazon Web Services – Aptus Data Labs\n\nCOMPANY\n\nAptus Data Labs\n\nAptus Data Labs delivers tailored Data Science and AI solutions, leveraging expert teams and advanced technology to transform data into actionable insights. We enhance business outcomes, provide ongoing support, and ensure top security standards.\n\nAbout Us\n\nCareer Opportunities\n\nContact us\n\nQuick contact\n\nAddress\n\nNovel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068\n\nCall Us\n\n+91 8861769911\n\n+91 8861799911\n\nMail Us\n\n[email\xa0protected]\n\nWorking Hours\n\nMonday to Friday : 9:30am - 6pm\n\nSaturday & Sunday : Closed\n\nHO Directions\n\nPLATFORMS\n\nAptPlan.ai\n\nIntelligent Supply Chain Planning\n\nAptCheck\n\nAI powered documentation compilation-evaluation Application\n\nAptveri5\n\nAI-powered Auditing solutions\n\nAptSpend\n\nTrack your Income and Expenses with Ease\n\nAptGenAI\n\nGenerative AI Framework for Smart Business Solutions\n\nUse Cases\n\nOur ready solutions can be implemented in various industries as business processes are largely common across domains. Some, such as AptCheck, may not straddle every business, the use cases are provided for each solution if you download the comprehensive brochure provided for every solution.\n\nCase Study\n\nData, Cloud, Analytics and AI case studies\n\nSERVICES\n\nOur Services\n\nAdvisory Services\n\nData Engineering & Value Management\n\nCloud Solutions\n\nArtificial Intelligence & Analytics\n\nGenerative AI\n\nAnalytics Modernization & Migration\n\nIntelligent Application Development and Integrations\n\nOperationalize data & AI platform\n\nProduction Support\n\nDIGITAL TRANSFORMATION\n\nEmbrace cloud-based infrastructure to enable flexible and scalable data storage, processing, and analysis.\n\nData & AI Accelerators\n\nIndustry & Business Focus\n\nINSIGHTS LAB\n\nOur Partners\n\nAmazon Web Services\n\nGoogle Cloud Platform\n\nAltair\n\nMicrosoft Azure\n\nVertica\n\nDataStax\n\nIBM\n\nYellowfin\n\nUiPath\n\nResources\n\nUnlock the power of data science and analytics - explore our blog, case studies, and partner insights.\n\nCase Studies\n\nBlog\n\nBLOGS\n\nX\n\nREQUEST A DEMO\n\nCompany\n\nAbout us  Career  Contact Us\n\nPlatforms\n\nAptPlan  AptCheck  AptVeri5  AptSpend  AptGenAI\n\nServices\n\nAdvisory Service  Data Engineering & Value Management  Cloud Solutions  Artificial Intelligence & Analytics  Generative AI  Analytical Modernization & Migrations  Intelligent Application Development and Integrations  Operationalize Data & AI platform  Production Support\n\nInsights Lab\n\nIBM  Amazon Web Services  Google Cloud Platform  DataStax  Yellowfin  Altair  Vertica  UiPath  Microsoft Azure\n\nBlog\n\nCase Study\n\nRequest a Demo\n\nX\n\nAmazon Web Services\n\nAptus Data Labs is the APN Consulting partner of AWS, one of the world’s top cloud providers, helping enterprises in their digital journey. This partnership enables Aptus Data Labs to leverage the full range of AWS services, AWS Cloud services, AWS Platform, and technologies.\n\nConnect with us\n\nAWS Services we offer\n\nData Management and Analytics\n\nWe assist with data management and analytics using AWS services like RDS, Redshift, and QuickSight.\n\nBig Data Processing and Analytics\n\nWe assist with big data processing using AWS services like EMR, Kinesis, and Redshift for real-time analysis.\n\nCloud Migration and Deployment\n\nWe help migrate and deploy applications to the cloud using AWS ECS, Elastic Beanstalk, and EKS.\n\nMachine Learning and Artificial Intelligence\n\nWe offer AI/ML solutions with AWS services like SageMaker, Rekognition, and Transcribe for intelligent applications.\n\nCloud Cost Optimization and Management\n\nWe optimize cloud costs and resources on AWS, identify ...
# [INF0]: Successfully extracted the relevant chunks for answer generation
# [INFO]: No of chunks extracted: 6
# [INFO]: Generating answer to the given query.

# %%
ans
# Out:
# {'chatbot_response': 'Aptus Data Labs offers a range of services including advisory services, data engineering and value management, cloud solutions, artificial intelligence and analytics, generative AI, analytics modernization and migration, intelligent application development and integrations, operationalizing data and AI platforms, and production support. They are particularly recognized for leveraging Amazon Web Services (AWS) to provide cloud computing solutions, data management, AI/ML solutions, and cloud-native application development.',
#  'sources': ['https://aptusdatalabs.com/amazon-web-services/',
#   'https://aptusdatalabs.com/cloud-solutions/',
#   'https://aptusdatalabs.com/',
#   'https://aptusdatalabs.com/terms-and-conditions/',
#   'https://aptusdatalabs.com/case-study/',
#   'https://aptusdatalabs.com/industry-business-focus/']}

# %%
ans

# %%
# retriever = document_wise_dbs[0].as_retriever(
#                 search_type="similarity_score_threshold",
#                 search_kwargs={"score_threshold": 0.6,
#                                 "k": 5}    
#             )
            
            
# docs = retriever.invoke(user_query)       
# docs

# %%
docs[1].metadata
# Out:
# {'source': 'https://aptusdatalabs.com/cloud-solutions/',
#  'loc': 'https://aptusdatalabs.com/cloud-solutions/',
#  'lastmod': '2024-09-16T10:19:53+00:00'}

# %%
results = document_wise_dbs[0].similarity_search(
    "Aptus data labs services",
    k=2,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * Aptus Data Labs
#
# COMPANY
#
# Aptus Data Labs
#
# Aptus Data Labs delivers tailored Data Science and AI solutions, leveraging expert teams and advanced technology to transform data into actionable insights. We enhance business outcomes, provide ongoing support, and ensure top security standards.
#
# About Us
#
# Career Opportunities
#
# Contact us
#
# Quick contact
#
# Address
#
# Novel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068
#
# Call Us
#
# +91 8861769911
#
# +91 8861799911
#
# Mail Us
#
# [email protected]
#
# Working Hours
#
# Monday to Friday : 9:30am - 6pm
#
# Saturday & Sunday : Closed
#
# HO Directions
#
# PLATFORMS
#
# AptPlan.ai
#
# Intelligent Supply Chain Planning
#
# AptCheck
#
# AI powered documentation compilation-evaluation Application
#
# Aptveri5
#
# AI-powered Auditing solutions
#
# AptSpend
#
# Track your Income and Expenses with Ease
#
# AptGenAI
#
# Generative AI Framework for Smart Business Solutions
#
# Use Cases
#
# Our ready solutions can be implemented in various industries as business processes are largely common across domains. Some, such as AptCheck, may not straddle every business, the use cases are provided for each solution if you download the comprehensive brochure provided for every solution.
#
# Case Study
#
# Data, Cloud, Analytics and AI case studies
#
# SERVICES
#
# Our Services
#
# Advisory Services
#
# Data Engineering & Value Management
#
# Cloud Solutions
#
# Artificial Intelligence & Analytics
#
# Generative AI
#
# Analytics Modernization & Migration
#
# Intelligent Application Development and Integrations
#
# Operationalize data & AI platform
#
# Production Support
#
# DIGITAL TRANSFORMATION
#
# Embrace cloud-based infrastructure to enable flexible and scalable data storage, processing, and analysis.
#
# Data & AI Accelerators
#
# Industry & Business Focus
#
# INSIGHTS LAB
#
# Our Partners
#
# Amazon Web Services
#
# Google Cloud Platform
#
# Altair
#
# Microsoft Azure
#
# Vertica
#
# DataStax
#
# IBM
#
# Yellowfin
#
# UiPath
#
# Resources
#
# Unlock the power of data science and analytics - explore our blog, case studies, and partner insights.
#
# Case Studies
#
# Blog
#
# BLOGS
#
# X
#
# REQUEST A DEMO
#
# Company
#
# About us  Career  Contact Us
#
# Platforms
#
# AptPlan  AptCheck  AptVeri5  AptSpend  AptGenAI
#
# Services
#
# Advisory Service  Data Engineering & Value Management  Cloud Solutions  Artificial Intelligence & Analytics  Generative AI  Analytical Modernization & Migrations  Intelligent Application Development and Integrations  Operationalize Data & AI platform  Production Support
#
# Insights Lab
#
# IBM  Amazon Web Services  Google Cloud Platform  DataStax  Yellowfin  Altair  Vertica  UiPath  Microsoft Azure
#
# Blog
#
# Case Study
#
# Request a Demo
#
# X
#
# Slide 1Aptus Data LabsTransform Business Realities with Intelligent Analytics SolutionsOvercome Complex Business Challenges with PRECISION using our Data and AI advanced capabilities.
#
# Know About UsSlide 2Generative AIReinventing Businesses with Generative AIHelping you to move away from silo based Business Use-Cases to broad-based integrated solutions.
#
# Generative AI CapabilitySlide 3RecognitionRecognised Leaders in Analytics & AI: Everest Group Peak Matrix 2024Leader in Innovation, Competencies & Imbued with a Mindset of Excellence; Customer Success Assured
#
# Everest Group Report
#
# Innovation with Advanced Analytics, AI & Emerging Technologies
#
# We are a leading innovator in Data and Artificial Intelligence solutions, dedicated to transforming businesses through the power of Advanced Data Analytics, AI, and Generative AI. By leveraging cutting-edge technologies, we deliver services and solutions that optimize operations and drive sustainable growth, leading to greater business efficiency and effectiveness.
#
# Book a Calendar
#
# Watch Video
#
# Vision
#
# To be the preferred solutions provider across industries, optimizing global operations with innovative analytics & AI.
#
# Mission
#
# Strengthen Data & AI capabilities, partner with leading digital OEMs, and invest continuously in our talented workforce.
#
# Values
#
# Innovation, Development, Evolution, Efficiency, Progress, Integrity, Adaption and customer satisfaction to foster growth.
#
# Unleashing Hidden Treasures in your Data: Engineering AI Solutions To Keep You Ahead
#
# Aptus Data Labs specializes in Data and AI solutions, leveraging emerging technologies to transform your data into actionable insights leading to greater business efficiency and effectiveness.
#
# Whether It’s In Pharmaceuticals, Banking and Fintech, Retail and Manufacturing, we provide customized solutions for any business sector.
#
# 0
#
# +
#
# Data and AI Accelerators
#
# 0
#
# +
#
# Patents and Proprietary Solutions
#
# 0
#
# +
#
# Curated Business Case Studies
#
# 0
#
# +
#
# Strong Data and Al Team
#
# 0
#
# +
#
# Our Satisfied Global Clients
#
# Transforming Industries with Tailored Data and AI Solutions
#
# Pharmaceuticals Enhance drug discovery, clinical trials, personalized medicine, and supply chain optimization with comprehensive data analysis. Ensure data integrity, security, and privacy, driving growth and improved patient outcomes. Learn More
#
# Manufacturing & Supply Chain Improve efficiency with predictive maintenance, inventory optimization, and enhanced production control. Ensure data integrity, security, and cost reduction through seamless data integration. Learn More
#
# Banking & Fintech Integrate data, detect fraud, assess credit risk, and provide personalized customer experiences. Boost efficiency, risk management, and compliance with advanced AI solutions. Learn More
#
# Retail & Consumer Goods Gain insights into customer behavior, inventory, and sales. Personalize experiences, optimize inventory, and improve marketing efforts, ensuring data integrity and boosting sales. Learn More
#
# Technology Enhance product performance and user behavior insights. Optimize IT operations, improve security, and ensure data integrity and privacy, driving innovation and maintaining competitiveness. Learn More
#
# Innovate-Implement-Transform
#
# Industry Specific Solutions
#
# Our customer-centric approach ensures tailored solutions that enhance business efficiency, decision-making, and innovation across various industries. From Pharmaceuticals to Banking & Fintech, Retail, and Manufacturing & Supply Chain, we provide customized solutions for every sector. Committed to excellence, we help organizations navigate the digital landscape, achieve success, and stay competitive.
#
# Read Our Blogs
#
# Our Case Studies
#
# What makes us unique?
#
# 'Customer-First' Attitude
#
# Prioritizing customer needs and building solutions accordingly.
#
# Data to Decison approach
#
# Delivering measurable results that result in positive impact on businesses.
#
# Business Solutions
#
# Real-world applications of Al & emerging technologies to drive business growth.
#
# 24/7 Real Time Support & Services
#
# Investing in our team to deliver top-notch service.
#
# Expertise in Building Products and Solutions
#
# We Excel in Creating Innovative, Industry-focused Solutions
#
# Data, AI/ML & Generative AI Competencies
#
# Expertise in the latest technologies and techniques.
#
# Read Our Case Studies
#
# Propelling Hyperscale Enterprises with Elite Ecosystem Partnerships
#
# Get Ahead & Stay Ahead with our Intelligent Services
#
# Leverage over 1000+ years of combined expertise from our Data Scientists and AI Engineers to drive your business forward.
#
# Strategic Advisory and Consulting Services
#
# Elevate your business with Aptus Data Lab's expert advisory services on Data and Artificial Intelligence Strategies. Leverage cutting-edge technologies and industry best practices for transformative, data-driven success and innovation.
#
# Read More
#
# Data Engineering & Value Management
#
# Transform raw data into actionable insights with Aptus Data Lab's robust data engineering solutions. Our tailored approach ensures agility, security, and compliance for confident decision-making and sustained business growth.
#
# Read More
#
# Scalable Cloud Computing Solutions
#
# Accelerate your business with Aptus Data Lab's comprehensive Cloud Computing Solutions. Unlock unparalleled innovation, scalability, and security for seamless integration and continuous advancement in today's competitive digital landscape.
#
# Read More
#
# Analytics and Artificial Intelligence Solutions
#
# Empower your business with Aptus Data Labs' advanced Artificial Intelligence and Analytics Solutions. Accelerate automation, unlock valuable insights, and drive a formidable competitive advantage in the dynamic digital age.
#
# Read More
#
# Generative AI Services and Solutions
#
# Transform your business with Aptus Data Labs' Generative AI services and solutions, offering advanced content creation, intelligent automation, and AI-driven insights. Our expertise ensures innovative, efficient, and ethical AI integration.
#
# Read More
#
# Analytics Modernization & Migration
#
# Unleash your business's potential with Aptus Data Labs' Generative AI solutions. Drive unparalleled creativity, innovation, and competitive advantage through advanced AI techniques and bespoke expertise tailored to your needs.
#
# Read More
#
# Intelligent Application Development & Integrations
#
# Transform your business with Aptus Data Labs' Intelligent Application Development & Integrations services. Leverage advanced technologies & seamless integrations for innovative, scalable, & efficient applications & business success.
#
# Read More
#
# Operationalize "Data & Artificial Intelligence  Platform"
#
# Streamline operations by operationalizing your Data and Artificial Intelligence Platform with Aptus Data Labs. Ensure robust, scalable, and secure deployment of analytical models and applications for sustained business impact.
#
# Read More
#
# 24/7 Comprehensive Production Support
#
# Ensure seamless operations with Aptus Data Labs' Production Support services. Benefit from 24/7 monitoring, proactive issue resolution, and tailored IT solutions to maximize efficiency and productivity continuously.
#
# Read More
#
# AptPlan.ai
#
# AptPlan revolutionizes supply chain planning with AI-ML powered demand forecasting, leveraging vast data and multivariate analyses to deliver precise, actionable insights for diverse Store Keeping Units.
#
# Innovative Demand Sensing
#
# Automated Operations Scheduling
#
# Automated Inventory Management
#
# Optimal Reorder Levels
#
# Precise Demand Forecasting
#
# Supply Distribution Planning
#
# AptPlan:  AI-Powered Intelligent Supply Chain Solution
#
# Explore AptPlan.ai
#
# AptCheck: AI-Powered Document Grader Application
#
# AptCheck
#
# Enhancing document evaluation with AI precision, ensuring FDA (equivalent) compliance and increased compilation productivity through Natural Language Processing (NLP).
#
# FDA (equivalent) compliance standards
#
# Objective quality control
#
# Automated evaluation
#
# User-friendly dashboard
#
# Boosted productivity and accuracy
#
# NLP evaluation scores
#
# Explore AptCheck
#
# AptVeri5: AI-Powered NextGen Auditing Solution
#
# Aptveri5
#
# Redefining auditing with AI and Generative AI technologies, offering automated verification and advanced risk mitigation for 100% compliance to regulations and Board imperatives.
#
# Scheduled background auditing
#
# Saves countless man hours
#
# Improved corporate governance
#
# Comprehensive final report
#
# Increased efficiency and accuracy
#
# Controlled Audit
#
# Explore AptVeri5
#
# AptSpend: AI-Driven Spend Analytics Platform
#
# AptSpend
#
# Improve your cash flow with AI-driven expense tracking, SMS classification, and insightful analytics for smarter spending decisions.
#
# Automated SMS Classification (Alerts)
#
# Categorical and Merchant-Wise Classification
#
# Payment Reminders
#
# User Friendly App and Dashboard
#
# Comprehensive Spend Analysis
#
# Positive Cash Flow
#
# Explore AptSpend
#
# Trusted by numerous Fortune 1000 companies
#
# What our customers have to say about our solutions & services
#
# Solving Complex Business Problems
#
# Define The Customer Success Story
#
# Define The Customer Success Story
#
# EXPLORE MORE SUCCESS STORIES
#
# Recognized By Renowned Industry Leaders for Our Pathfinding
#
# Lorem ipsum
#
# Lorem ipsum dolor sit amet, consectetur adipisi cing elit, sed do eius mod tempor incididunt ut  labore et dolore magna aliqua.
#
# Read More
#
# Dolor sit amet
#
# Lorem ipsum dolor sit amet, consectetur adipisi cing elit, sed do eius mod tempor incididunt ut  labore et dolore magna aliqua.
#
# Read More
#
# Dolor sit amet
#
# Lorem ipsum dolor sit amet, consectetur adipisi cing elit, sed do eius mod tempor incididunt ut  labore et dolore magna aliqua.
#
# Read More
#
# Latest From The Lab
#
# Blogs
#
# Stay ahead with the latest trends and innovations in technology.
#
# Demand Sensing Optimising Supply and Demand Mismatch
#
# Read More
#
# 28
#
# Jul
#
# Big Data for Digital Marketing and Moment of Truth
#
# Read More
#
# 28
#
# Jul
#
# Leveraging Predictive Analytics for Supply Chain Management
#
# Read More
#
# 28
#
# Jul
#
# The Advantages of Cloud- Based Data Analytics Solutions
#
# Read More
#
# 28
#
# Jul
#
# The Challenges of Data Privacy and Security in the Age of Big Data
#
# Read More
#
# 28
#
# Jul
#
# Get In touch with our  Experts
#
# Are you planning to take your business to the next level with data science? We invite you to connect with us today to schedule a consultation. Our team will work with you, to assess your current data landscape and develop a customized solution that will help you drive growth and get ahead in the rapidly changing technology environment.
#
# GET IN TOUCH
#
# Our team of experts helps businesses make informed decisions and drive growth through customized solutions. Contact us to learn more about how our services can help your business to get ahead & stay ahead.
#
# Platform
#
# AptPlan.ai
#
# AptCheck
#
# Aptveri5
#
# AptSpend
#
# AptGenAI
#
# Services
#
# Advisory Services
#
# Data Engineering & Value Management
#
# Cloud Solutions
#
# Artificial Intelligence & Analytics
#
# Generative AI
#
# Analytics Modernization & Migration
#
# Intelligent Application Development and Integrations
#
# Operationalize data & AI platform
#
# Production Support
#
# About
#
# Company
#
# Blog
#
# Case Study
#
# Careers
#
# Contact
#
# Novel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068
#
# [email protected]
#
# ©2024-25. Aptus Data Labs. All Rights Reserved.
#
# Privacy Policy
#
# Terms & Conditions
#
# Our team of experts helps businesses make informed decisions and drive growth through customized solutions. Contact us to learn more about how our services can help your business to get ahead & stay ahead.
#
# Platform
#
# About
#
# AptPlan.ai
#
# AptCheck
#
# AptCheck
#
# Aptveri5
#
# AptSpend
#
# AptGenAI
#
# Company
#
# Blog
#
# Case Study
#
# Careers
#
# Contact
#
# Services
#
# Advisory Services
#
# Data Engineering & Value Management
#
# Cloud Solutions
#
# Artificial Intelligence & Analytics
#
# Generative AI
#
# Analytics Modernization & Migration
#
# Intelligent Application Development and Integrations
#
# Operationalize data & AI platform
#
# Production Support
#
# Novel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068
#
# [email protected]
#
# ©2024-25. Aptus Data Labs. All Rights Reserved.
#
# Privacy Policy
#
# Terms & Conditions [{'source': 'https://aptusdatalabs.com/', 'loc': 'https://aptusdatalabs.com/', 'lastmod': '2024-09-23T12:45:11+00:00'}]
# * Amazon Web Services – Aptus Data Labs
#
# COMPANY
#
# Aptus Data Labs
#
# Aptus Data Labs delivers tailored Data Science and AI solutions, leveraging expert teams and advanced technology to transform data into actionable insights. We enhance business outcomes, provide ongoing support, and ensure top security standards.
#
# About Us
#
# Career Opportunities
#
# Contact us
#
# Quick contact
#
# Address
#
# Novel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068
#
# Call Us
#
# +91 8861769911
#
# +91 8861799911
#
# Mail Us
#
# [email protected]
#
# Working Hours
#
# Monday to Friday : 9:30am - 6pm
#
# Saturday & Sunday : Closed
#
# HO Directions
#
# PLATFORMS
#
# AptPlan.ai
#
# Intelligent Supply Chain Planning
#
# AptCheck
#
# AI powered documentation compilation-evaluation Application
#
# Aptveri5
#
# AI-powered Auditing solutions
#
# AptSpend
#
# Track your Income and Expenses with Ease
#
# AptGenAI
#
# Generative AI Framework for Smart Business Solutions
#
# Use Cases
#
# Our ready solutions can be implemented in various industries as business processes are largely common across domains. Some, such as AptCheck, may not straddle every business, the use cases are provided for each solution if you download the comprehensive brochure provided for every solution.
#
# Case Study
#
# Data, Cloud, Analytics and AI case studies
#
# SERVICES
#
# Our Services
#
# Advisory Services
#
# Data Engineering & Value Management
#
# Cloud Solutions
#
# Artificial Intelligence & Analytics
#
# Generative AI
#
# Analytics Modernization & Migration
#
# Intelligent Application Development and Integrations
#
# Operationalize data & AI platform
#
# Production Support
#
# DIGITAL TRANSFORMATION
#
# Embrace cloud-based infrastructure to enable flexible and scalable data storage, processing, and analysis.
#
# Data & AI Accelerators
#
# Industry & Business Focus
#
# INSIGHTS LAB
#
# Our Partners
#
# Amazon Web Services
#
# Google Cloud Platform
#
# Altair
#
# Microsoft Azure
#
# Vertica
#
# DataStax
#
# IBM
#
# Yellowfin
#
# UiPath
#
# Resources
#
# Unlock the power of data science and analytics - explore our blog, case studies, and partner insights.
#
# Case Studies
#
# Blog
#
# BLOGS
#
# X
#
# REQUEST A DEMO
#
# Company
#
# About us  Career  Contact Us
#
# Platforms
#
# AptPlan  AptCheck  AptVeri5  AptSpend  AptGenAI
#
# Services
#
# Advisory Service  Data Engineering & Value Management  Cloud Solutions  Artificial Intelligence & Analytics  Generative AI  Analytical Modernization & Migrations  Intelligent Application Development and Integrations  Operationalize Data & AI platform  Production Support
#
# Insights Lab
#
# IBM  Amazon Web Services  Google Cloud Platform  DataStax  Yellowfin  Altair  Vertica  UiPath  Microsoft Azure
#
# Blog
#
# Case Study
#
# Request a Demo
#
# X
#
# Amazon Web Services
#
# Aptus Data Labs is the APN Consulting partner of AWS, one of the world’s top cloud providers, helping enterprises in their digital journey. This partnership enables Aptus Data Labs to leverage the full range of AWS services, AWS Cloud services, AWS Platform, and technologies.
#
# Connect with us
#
# AWS Services we offer
#
# Data Management and Analytics
#
# We assist with data management and analytics using AWS services like RDS, Redshift, and QuickSight.
#
# Big Data Processing and Analytics
#
# We assist with big data processing using AWS services like EMR, Kinesis, and Redshift for real-time analysis.
#
# Cloud Migration and Deployment
#
# We help migrate and deploy applications to the cloud using AWS ECS, Elastic Beanstalk, and EKS.
#
# Machine Learning and Artificial Intelligence
#
# We offer AI/ML solutions with AWS services like SageMaker, Rekognition, and Transcribe for intelligent applications.
#
# Cloud Cost Optimization and Management
#
# We optimize cloud costs and resources on AWS, identifying savings and implementing cost management best practices.
#
# Cloud-Native Application Development
#
# We develop and deploy cloud-native applications using AWS Lambda, EC2, and S3 for efficient development
#
# AWS FAQ's
#
# We collaborate, we think, we create outside the box by building digital products and empowering brands.
#
# What is Amazon Web Services (AWS)?
#
# It provides a collection of remote computing services (also called web services) that make up a cloud computing platform, offered by Amazon.com. Additionally, these services operate from 12 geographical regions across the world.
#
# What are the benefits of using AWS?
#
# It offers a wide range of benefits, including scalability, flexibility, cost savings, security, compliance, global reach, and a wide variety of services and tools. Additionally, it ensures seamless integration with existing systems and processes, driving innovation and efficiency.
#
# How does AWS pricing work?
#
# AWS pricing is based on a pay-as-you-go model. Furthermore, you only pay for the services and resources you use. You can easily scale up or down as needed. There are no upfront costs or long-term commitments required.
#
# How secure is AWS?
#
# It provides a very high level of security, with a variety of security-related services and features. Furthermore, these include encryption, identity and access management, and a variety of compliance certifications.
#
# Can I use AWS for my business?
#
# Yes, It offers a wide range of services and tools that can be used by businesses of all sizes. Moreover, from small startups to large enterprise companies, AWS provides the infrastructure and resources to support the unique needs of different types of businesses.
#
# How does AWS compare to other cloud providers?
#
# They are among the top cloud providers, alongside Microsoft Azure and Google Cloud Platform. Furthermore, each provider offers a similar set of services. However, they may differ in terms of pricing, features, and ease of use.
#
# Get In touch with our  Experts
#
# Are you planning to take your business to the next level with data science? We invite you to connect with us today to schedule a consultation. Our team will work with you, to assess your current data landscape and develop a customized solution that will help you gain valuable insights and drive growth.
#
# GET IN TOUCH
#
# Our team of experts helps businesses make informed decisions and drive growth through customized solutions. Contact us to learn more about how our services can help your business to get ahead & stay ahead.
#
# Platform
#
# AptPlan.ai
#
# AptCheck
#
# Aptveri5
#
# AptSpend
#
# AptGenAI
#
# Services
#
# Advisory Services
#
# Data Engineering & Value Management
#
# Cloud Solutions
#
# Artificial Intelligence & Analytics
#
# Generative AI
#
# Analytics Modernization & Migration
#
# Intelligent Application Development and Integrations
#
# Operationalize data & AI platform
#
# Production Support
#
# About
#
# Company
#
# Blog
#
# Case Study
#
# Careers
#
# Contact
#
# Novel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068
#
# [email protected]
#
# ©2024-25. Aptus Data Labs. All Rights Reserved.
#
# Privacy Policy
#
# Terms & Conditions
#
# Our team of experts helps businesses make informed decisions and drive growth through customized solutions. Contact us to learn more about how our services can help your business to get ahead & stay ahead.
#
# Platform
#
# About
#
# AptPlan.ai
#
# AptCheck
#
# AptCheck
#
# Aptveri5
#
# AptSpend
#
# AptGenAI
#
# Company
#
# Blog
#
# Case Study
#
# Careers
#
# Contact
#
# Services
#
# Advisory Services
#
# Data Engineering & Value Management
#
# Cloud Solutions
#
# Artificial Intelligence & Analytics
#
# Generative AI
#
# Analytics Modernization & Migration
#
# Intelligent Application Development and Integrations
#
# Operationalize data & AI platform
#
# Production Support
#
# Novel Tech Park, #46/4, GB Palya, Near Kudlu Gate, Hosur Main Road, Bengaluru, India, Pin – 560068
#
# [email protected]
#
# ©2024-25. Aptus Data Labs. All Rights Reserved.
#
# Privacy Policy
#
# Terms & Conditions [{'source': 'https://aptusdatalabs.com/amazon-web-services/', 'loc': 'https://aptusdatalabs.com/amazon-web-services/', 'lastmod': '2024-09-14T11:13:51+00:00'}]

# %%
           
if __name__ == "__main__":
   
    faiss_folder = ".VECTOR_STORE/vector_idx"
    

    from IPython.display import Markdown, display
    


    questions = [
    "Compare the quarterly earnings reports of Tesla, Ford, and General Motors for the last two years to identify trends in profitability and market share.",
    "Analyze the marketing strategies of Coca-Cola, PepsiCo, and Dr Pepper Snapple Group from their recent marketing plans to determine the effectiveness of their campaigns.",
    "Evaluate the specifications and user reviews of the latest smartphone models from Apple, Samsung, and Google to compare performance, camera quality, and battery life.",
    "How do the compliance documents for the COVID-19 vaccine trials of Pfizer, Moderna, and Johnson & Johnson differ in terms of safety protocols and regulatory approvals?",
    "Compare the customer feedback reports from Airbnb, Vrbo, and Booking.com to analyze trends in user experience and service quality across platforms.",
    "Evaluate the sustainability reports of Unilever, Procter & Gamble, and Nestlé to compare their environmental impact initiatives and progress towards sustainability goals.",
    "How do the R&D expenditure reports of Google, Microsoft, and Amazon compare in the fields of artificial intelligence and machine learning over the past three years?",
    "Analyze the supply chain management strategies of Walmart, Target, and Costco, focusing on efficiency, logistics, and sustainability practices based on their annual reports.",
    "Compare the employee engagement surveys and HR policies of Amazon, Google, and Microsoft to identify differences in workplace culture and employee retention strategies.",
    "How do the patent filings in AI technology from IBM, Oracle, and NVIDIA compare over the past five years in terms of innovation and market impact?"
    ]

    # query=questions[0]
    query = "tell me about jv "
    document_wise_dbs = extract_docs_db(query=user_query, faiss_folder_path=faiss_folder)

    # Calling the llm for analysis
    ans =  ASK_Question_On_Your_Documents(query, faiss_folder) 

    # Display the result as Markdown in Jupyter
    # display(Markdown(ans))   
    print(ans)
